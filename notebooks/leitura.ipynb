# %%
import yfinance as yf
import pandas as pd

# %%
symbols = ['BTC-USD','ETH-USD','USDT-USD','SOL-USD','DOGE-USD']
start_date = '2018-01-01'
end_date = '2023-11-29'

# %%
# !pip install pyarrow fastparquet
# Out:
# Requirement already satisfied: pyarrow in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (14.0.1)
# Requirement already satisfied: fastparquet in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (2023.10.1)
# Requirement already satisfied: numpy>=1.16.6 in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from pyarrow) (1.26.2)
# Requirement already satisfied: pandas>=1.5.0 in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from fastparquet) (2.1.3)
# Requirement already satisfied: cramjam>=2.3 in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from fastparquet) (2.7.0)
# Requirement already satisfied: fsspec in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from fastparquet) (2023.10.0)
# Requirement already satisfied: packaging in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from fastparquet) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/holyvieri/miniconda3/envs/ia_eraylson/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)

# %%
def download_data(symbols):
    lista_dfs = []
    path = '/home/holyvieri/think-learn-ai/data/raw/'
    for symbol in symbols:
        path_full = path+symbol+'.parquet.gzip'
        df = yf.download(symbol, start= start_date, end=end_date)
        if df.shape[0]==0:
            print(f"A base {symbol} não está disponível.")
        else:
            df.to_parquet(path_full, compression='gzip')

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2018-01-01  0.009031  0.009063  0.008101  0.008909   0.008909   50616900
# 2018-01-02  0.008873  0.009598  0.008551  0.009145   0.009145   89424096
# 2018-01-03  0.009088  0.009584  0.008882  0.009320   0.009320   66349900
# 2018-01-04  0.009346  0.010036  0.008768  0.009644   0.009644  108986000
# 2018-01-05  0.009660  0.012283  0.009589  0.012167   0.012167  212383008
# ...              ...       ...       ...       ...        ...        ...
# 2023-11-24  0.076199  0.078429  0.076149  0.078217   0.078217  401116993
# 2023-11-25  0.078216  0.079105  0.077763  0.078955   0.078955  291859035
# 2023-11-26  0.078952  0.078980  0.076346  0.078704   0.078704  343339848
# 2023-11-27  0.078690  0.081320  0.077089  0.078788   0.078788  743996999
# 2023-11-28  0.078792  0.081031  0.077037  0.081009   0.081009  618900678
#
# [2158 rows x 6 columns]
